# %%
from anndata import AnnData
from main import integrate_data
from utils import data_preprocess,compute_ASW,compute_ARI

import scanpy as sc
import numpy as np
import time
import os
import pandas as pd

# %%
input_dir = 'input'
res_dir = 'result'
method_name = 'IMG'
data_name = 'panc'

# %%
start_time = time.time()
adata = sc.read_loom("../data/panc8.loom",sparse = False)
adata.obs['batch'] = adata.obs['batch'].astype('category')
adata.obs.batch.value_counts()
# Out:
# indrop        8569
# smartseq2     2394
# celseq2       2285
# celseq        1004
# fluidigmc1     638
# Name: batch, dtype: int64

# %%
adata.X = np.float32(np.int32(adata.X))
adata = data_preprocess(adata)
# Out:
# Establishing Adata for Next Step...
# /hpcfiles/users/zcg/.conda/envs/zcg/lib/python3.7/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)
# Trying to set attribute `.obs` of view, copying.
# PreProcess Done.

# %%
balance_sampling = False
batch_num = len(adata.obs.batch.unique())

# %%
# Whether to use batch balance sampling strategy
if balance_sampling:
    total_num = len(adata)
    per_num = int(total_num/batch_num)

    X = adata.X
    y = adata.obs.batch.tolist()

    from collections import Counter
    print(Counter(y))

    over_sample = {}
    under_sample = {}
    dict_y = Counter(y)
    for key in dict_y.keys():
        if dict_y[key] >= per_num * 1.1:
            under_sample[key] = int(per_num * 1.1)
        elif dict_y[key] <= per_num * 0.9:
            over_sample[key] = int(per_num * 0.9)

    from imblearn.over_sampling import SMOTE
    smo = SMOTE(sampling_strategy=over_sample,random_state=42)
    X_smo, y_smo = smo.fit_resample(X, y)
    print(Counter(y_smo))

    from imblearn.under_sampling import RandomUnderSampler
    cc = RandomUnderSampler(sampling_strategy=under_sample,random_state=0)
    X_resampled, y_resampled = cc.fit_resample(X_smo, y_smo)
    print(Counter(y_resampled))
    import pandas as pd
    obs = pd.DataFrame()
    obs['batch'] = y_resampled
    ppd_adata = AnnData(X_resampled,obs=obs)
else:
    ppd_adata = adata

# %%
sc.tl.pca(ppd_adata,n_comps=256)

# %%
out= integrate_data(ppd_adata, adata, batch_key='batch', n_epochs=100, mnn_times=5, len_weight=5, self_nbs=15, other_nbs=1, batch_size=1024, n_critic=100,batch_num=batch_num,balance_sampling=balance_sampling,overlap=True,under_sample=False,under_sample_num=50000)
# Out:
# Number of samples per batch: 2978
# Times: 0
# celseq<——>celseq2
# /hpcfiles/users/zcg/.conda/envs/zcg/lib/python3.7/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)
# celseq<——>smartseq2
# celseq<——>fluidigmc1
# celseq<——>indrop
# celseq2<——>smartseq2
# celseq2<——>fluidigmc1
# celseq2<——>indrop
# smartseq2<——>fluidigmc1
# smartseq2<——>indrop
# fluidigmc1<——>indrop
# Times: 1
# celseq<——>celseq2
# celseq<——>smartseq2
# celseq<——>fluidigmc1
# celseq<——>indrop
# celseq2<——>smartseq2
# celseq2<——>fluidigmc1
# celseq2<——>indrop
# smartseq2<——>fluidigmc1
# smartseq2<——>indrop
# fluidigmc1<——>indrop
# Times: 2
# celseq<——>celseq2
# celseq<——>smartseq2
# celseq<——>fluidigmc1
# celseq<——>indrop
# celseq2<——>smartseq2
# celseq2<——>fluidigmc1
# celseq2<——>indrop
# smartseq2<——>fluidigmc1
# smartseq2<——>indrop
# fluidigmc1<——>indrop
# Times: 3
# celseq<——>celseq2
# celseq<——>smartseq2
# celseq<——>fluidigmc1
# celseq<——>indrop
# celseq2<——>smartseq2
# celseq2<——>fluidigmc1
# celseq2<——>indrop
# smartseq2<——>fluidigmc1
# smartseq2<——>indrop
# fluidigmc1<——>indrop
# Times: 4
# celseq<——>celseq2
# celseq<——>smartseq2
# celseq<——>fluidigmc1
# celseq<——>indrop
# celseq2<——>smartseq2
# celseq2<——>fluidigmc1
# celseq2<——>indrop
# smartseq2<——>fluidigmc1
# smartseq2<——>indrop
# fluidigmc1<——>indrop
# Find MNNs time-consuming :28.840447187423706
# The percentage of MNN paired cells in the total cells : 0.30926796507723303
# The final number of subgraphs :2063
# Counter({5: 1407, 4: 355, 3: 167, 2: 134})
# Dataset size : 175875
# Time-consuming to build dataset: 66.89839124679565
# [Epoch 1/100] [D loss: 0.083849] [G loss: 0.089820] [AE loss: 169.802734]
# [Epoch 2/100] [D loss: -3.282563] [G loss: -0.816909] [AE loss: 131.055573]
# [Epoch 3/100] [D loss: -4.563626] [G loss: -3.841118] [AE loss: 118.443176]
# [Epoch 4/100] [D loss: -4.650987] [G loss: -4.304762] [AE loss: 112.241089]
# [Epoch 5/100] [D loss: -4.685682] [G loss: -4.327918] [AE loss: 108.231514]
# [Epoch 6/100] [D loss: -4.770641] [G loss: -4.411548] [AE loss: 103.931419]
# [Epoch 7/100] [D loss: -4.831051] [G loss: -4.128906] [AE loss: 98.573807]
# [Epoch 8/100] [D loss: -4.900535] [G loss: -3.924123] [AE loss: 95.924637]
# [Epoch 9/100] [D loss: -4.867026] [G loss: -3.750335] [AE loss: 93.788002]
# [Epoch 10/100] [D loss: -4.867261] [G loss: -3.914461] [AE loss: 91.380516]
# [Epoch 11/100] [D loss: -4.824892] [G loss: -3.629690] [AE loss: 88.419380]
# [Epoch 12/100] [D loss: -4.785059] [G loss: -3.473592] [AE loss: 85.712761]
# [Epoch 13/100] [D loss: -4.715879] [G loss: -3.804830] [AE loss: 82.537209]
# [Epoch 14/100] [D loss: -4.673478] [G loss: -3.637511] [AE loss: 81.972916]
# [Epoch 15/100] [D loss: -4.562045] [G loss: -3.876304] [AE loss: 81.366379]
# [Epoch 16/100] [D loss: -4.596786] [G loss: -4.161393] [AE loss: 80.141098]
# [Epoch 17/100] [D loss: -4.685638] [G loss: -3.809859] [AE loss: 80.004143]
# [Epoch 18/100] [D loss: -4.569638] [G loss: -3.850049] [AE loss: 78.289001]
# [Epoch 19/100] [D loss: -4.508110] [G loss: -3.770478] [AE loss: 75.975311]
# [Epoch 20/100] [D loss: -4.474845] [G loss: -3.776230] [AE loss: 74.401924]
# [Epoch 21/100] [D loss: -4.400910] [G loss: -3.797343] [AE loss: 75.073151]
# [Epoch 22/100] [D loss: -4.490809] [G loss: -4.118358] [AE loss: 73.482986]
# [Epoch 88/100] [D loss: -3.953280] [G loss: -3.506709] [AE loss: 55.599968]
# [Epoch 89/100] [D loss: -3.917073] [G loss: -3.500640] [AE loss: 56.870506]
# [Epoch 90/100] [D loss: -3.830489] [G loss: -3.344118] [AE loss: 54.885929]
# [Epoch 91/100] [D loss: -3.912877] [G loss: -3.305703] [AE loss: 55.845901]
# [Epoch 92/100] [D loss: -3.899831] [G loss: -3.415525] [AE loss: 54.986870]
# [Epoch 93/100] [D loss: -3.801349] [G loss: -3.494422] [AE loss: 56.367825]
# [Epoch 94/100] [D loss: -3.983167] [G loss: -3.734443] [AE loss: 55.876213]
# [Epoch 95/100] [D loss: -3.853015] [G loss: -3.195282] [AE loss: 54.365063]
# [Epoch 96/100] [D loss: -3.904923] [G loss: -3.867684] [AE loss: 55.248722]
# [Epoch 97/100] [D loss: -4.009891] [G loss: -3.236000] [AE loss: 56.752457]
# [Epoch 98/100] [D loss: -3.928297] [G loss: -3.251870] [AE loss: 55.230278]
# [Epoch 99/100] [D loss: -3.807828] [G loss: -3.088842] [AE loss: 54.070930]
# [Epoch 100/100] [D loss: -3.940515] [G loss: -3.136409] [AE loss: 54.602299]

# %%
end_time = time.time()
print("耗时为: "+str(end_time-start_time))
# Out:
# 耗时为: 188.33875036239624

# %%
out = AnnData(out,adata.obs)

# %%
sc.pp.neighbors(out)
sc.tl.umap(out)
# Out:
# WARNING: You’re trying to run this on 2000 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.

# %%
sc.pl.umap(out,color=['batch'],legend_fontsize=12,frameon=False,save='_'+method_name+'_'+data_name+'_batch.png')
sc.pl.umap(out,color=['celltype'],legend_fontsize=12,frameon=False,save='_'+method_name+'_'+data_name+'_celltype.png')
# Out:
# ... storing 'ClusterName' as categorical
# ... storing 'celltype' as categorical
# WARNING: saving figure to file figures/umap_IMG_panc_batch.png
# WARNING: saving figure to file figures/umap_IMG_panc_celltype.png

# %%
arr = out.obsm['X_pca']
batch_label = out.obs['batch'].tolist()
cell_label = out.obs['celltype'].tolist()
asw_batch_score, asw_celltype_score = compute_ASW(arr, batch_label, cell_label)
print("ASW score：")
print(asw_batch_score,asw_celltype_score)

print("ARI score：")
batch_ARI, cell_ARI = compute_ARI(out)
print(batch_ARI, cell_ARI)
# Out:
# ASW score：
# -0.1600525 0.5424346
# ARI score：
# 0.011832822936351996 0.8647719210542721

# %%
matrix_path = os.path.join(res_dir,method_name+'_'+data_name+'_matrix.csv')
meta_path = os.path.join(res_dir,method_name+'_'+data_name+'_meta.csv')
lisi_path = os.path.join(res_dir,method_name+'_'+data_name+'_lisi.csv')

np.savetxt(matrix_path, out.obsm['X_pca'], delimiter=',')
data = {'batch':out.obs.batch.tolist(), 'celltype':out.obs.celltype.tolist()}
df = pd.DataFrame(data)
df.to_csv(meta_path,index=False)

process_args = "~/.conda/envs/zcg/bin/Rscript LISI.R "+matrix_path+" "+meta_path+" "+lisi_path
print(os.popen(process_args).read())
# Out:
# [1] "batch mean LISI: "
# [1] 2.274189
# [1] "celltype mean LISI: "
# [1] 1.046675
